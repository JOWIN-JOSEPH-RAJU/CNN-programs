# %%
from ultralytics import YOLO
import cv2
import cvzone
import math

# %% [markdown]
# # OBJECT DETECTION from Image

# %%
model=YOLO('yolov8n.pt')
results=model("img2.jpeg",show=True)
cv2.waitKey(10)
# Out:
# image 1/1 /Users/jowinjosephraju/Miniproject/img2.jpeg: 448x640 1 bench, 1 bowl, 3 chairs, 1 potted plant, 93.7ms
# Speed: 4.7ms preprocess, 93.7ms inference, 6.9ms postprocess per image at shape (1, 3, 448, 640)
# -1

# %% [markdown]
# ## OBJECT DETECTION from WEBCAMER

# %%
from ultralytics import YOLO
import cv2
import cvzone
import math


cap=cv2.VideoCapture(1)
cap.set(3,1280)
cap.set(4,720)
model=YOLO('yolov8n.pt')
classlabels = ["person", "bicycle", "car", "motorbike", "airplane", "bus", "train", "truck", "boat",
               "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
               "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "kangaroo",
               "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard",
               "sports ball", "kite", "baseball bat", "baseball glove", "tennis racket", "golf club",
               "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple",
               "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "cake", "chair", "sofa",
               "table", "bed", "toilet", "sink", "dishwasher", "oven", "stove", "microwave", "refrigerator",
               "monitor", "keyboard", "mouse", "laptop", "cell phone", "book", "clock", "vase", "scissors",
               "teddy bear", "hair dryer", "toothbrush"
              ]

while True:
    success,img=cap.read()
    results=model(img,stream=True)
   
    for r in results:
        boxes= r.boxes
        for box in boxes:
             x1,y1,x2,y2=box.xyxy[0]
             x1,y1,x2,y2=int( x1),int(y1),int(x2),int(y2)
             w,h=x2-x1,y2-y1
             cvzone.cornerRect(img,(x1,y1,w,h))
             
             conf=math.ceil((box.conf[0]*100))/100
          
             cls=int(box.cls[0])

             cvzone.putTextRect(img,f'{classlabels[cls]} {conf}',(max(0,x1),max(35,y1)))

             
       
    
    cv2.imshow("Image",img)
    cv2.waitKey(1)
# Out:
# 0: 384x640 1 person, 134.0ms
# Speed: 6.1ms preprocess, 134.0ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.4ms
# Speed: 1.8ms preprocess, 70.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 89.8ms
# Speed: 3.2ms preprocess, 89.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 146.2ms
# Speed: 3.4ms preprocess, 146.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.3ms
# Speed: 3.6ms preprocess, 95.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 81.1ms
# Speed: 2.9ms preprocess, 81.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 81.0ms
# Speed: 2.5ms preprocess, 81.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 83.0ms
# ...

# %% [markdown]
# # creating a program to count the cars

# %%
from ultralytics import YOLO
import cv2
import cvzone
import math


totalcount=0
cap=cv2.VideoCapture("john.mp4")
#cap.set(3,1280)
#cap.set(4,720)
model=YOLO('yolov8l.pt')
classlabels = ["person", "bicycle", "car", "motorbike", "airplane", "bus", "train", "truck", "boat",
               "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
               "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "kangaroo",
               "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard",
               "sports ball", "kite", "baseball bat", "baseball glove", "tennis racket", "golf club",
               "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple",
               "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "cake", "chair", "sofa",
               "table", "bed", "toilet", "sink", "dishwasher", "oven", "stove", "microwave", "refrigerator",
               "monitor", "keyboard", "mouse", "laptop", "cell phone", "book", "clock", "vase", "scissors",
               "teddy bear", "hair dryer", "toothbrush"
              ]



mask=cv2.imread("mask4.png")
if img.shape[:2] != mask.shape[:2]:
    mask = cv2.resize(mask, dsize=(img.shape[1], img.shape[0]))
    
limits=[423,297,673,297]
    

while True:
    success,img=cap.read()
    imgRegion=cv2.bitwise_and(img, mask)
    results=model(imgRegion,stream=True,device="mps")


   
    for r in results:
        boxes= r.boxes
        for box in boxes:
             x1,y1,x2,y2=box.xyxy[0]
             x1,y1,x2,y2=int( x1),int(y1),int(x2),int(y2)
             w,h=x2-x1,y2-y1

             cx,cy=x1+w//2,y1+h//2
             cv2.circle(img,(cx,cy),5,(255,0,255),cv2.FILLED)
             cvzone.cornerRect(img,(x1,y1,w,h))
             conf=math.ceil((box.conf[0]*100))/100
             cv2.line(img, (limits[0],limits[1]),(limits[2],limits[3]),color=(0,0,225), thickness=5)    
             cvzone.putTextRect(img,f' {conf}',(max(0,x1),max(35,y1)),scale=0.6,thickness=1,offset=3)
             
             cls=int(box.cls[0])
             if(classlabels[cls]=='car' and conf >.30):
                 cvzone.putTextRect(img,f'{classlabels[cls]} {conf}',(max(0,x1),max(35,y1)),scale=0.6,thickness=1,offset=3)
                  
             if limits[0]<cx<limits[2] and limits[1]-20<cy<limits[1]+20:
                 totalcount+=1
             cvzone.putTextRect(img, f' count:{totalcount}',(50,50))
 
                 
     

        
    
    cv2.imshow("Image",img)
    #cv2.imshow("image region",imgRegion)
    cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 35
#      33 while True:
#      34     success,img=cap.read()
# ---> 35     imgRegion=cv2.bitwise_and(img, mask)
#      36     results=model(imgRegion,stream=True,device="mps")
#      40     for r in results:
#
# error: OpenCV(4.9.0) /Users/xperience/GHA-OpenCV-Python2/_work/opencv-python/opencv-python/opencv/modules/core/src/arithm.cpp:214: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'binary_op'

# %%
from ultralytics import YOLO
import cv2
import cvzone
import math


totalcount=0
cap=cv2.VideoCapture("text.mp4")
cap.set(3,2880)
cap.set(4,1800)
model=YOLO('yolov8l.pt')

mask=cv2.imread("mask_data.png")

classlabels = ["person", "bicycle", "car", "motorbike", "airplane", "bus", "train", "truck", "boat",
               "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
               "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "kangaroo",
               "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard",
               "sports ball", "kite", "baseball bat", "baseball glove", "tennis racket", "golf club",
               "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple",
               "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "cake", "chair", "sofa",
               "table", "bed", "toilet", "sink", "dishwasher", "oven", "stove", "microwave", "refrigerator",
               "monitor", "keyboard", "mouse", "laptop", "cell phone", "book", "clock", "vase", "scissors",
               "teddy bear", "hair dryer", "toothbrush"
              ]





while True:

    
    success,img=cap.read()
   
   
    if img.shape[:2] != mask.shape[:2]:
        mask = cv2.resize(mask, dsize=(img.shape[1], img.shape[0]))

    if img.dtype != mask.dtype:
        mask = mask.astype(img.dtype)
   

    
    imgRegion=cv2.bitwise_and(img, mask)
    results=model(imgRegion,stream=True,device="mps")
    print
    
    
   

   
    for r in results:
        boxes= r.boxes
        for box in boxes:
            # Bounding Box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            w, h = x2 - x1, y2 - y1
            # Confidence
            conf = math.ceil((box.conf[0] * 100)) / 100
            
            # Class Name
            cls = int(box.cls[0])
            
            
            #Draw bounding box and label on the image
            if classlabels[cls]== "person":
               
                cvzone.cornerRect(imgRegion, (x1, y1, w, h))
                cvzone.putTextRect(imgRegion, f'{classlabels[cls]} {conf}', (max(0, x1), max(35, y1)), scale=1, thickness=1)
           
            
           
 
                 
     

        
    
    cv2.imshow("Image",img)
    cv2.imshow("image region",imgRegion)
    cv2.waitKey(1)
# Out:
# 0: 384x640 (no detections), 80.3ms
# Speed: 2.9ms preprocess, 80.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.3ms
# Speed: 2.4ms preprocess, 57.3ms inference, 23.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.5ms
# Speed: 2.2ms preprocess, 62.5ms inference, 26.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.4ms
# Speed: 3.3ms preprocess, 79.4ms inference, 42.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 127.9ms
# Speed: 2.7ms preprocess, 127.9ms inference, 56.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.0ms
# Speed: 3.4ms preprocess, 104.0ms inference, 35.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.3ms
# Speed: 3.5ms preprocess, 79.3ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
    if img.shape[:2] != mask.shape[:2]:
        mask = cv2.resize(mask,dsize=(img.shape[1], img.shape[0]) )
# Out:
#   Cell In[1], line 2
#     if img.shape[:2] != mask.shape[:2]:
#     ^
# IndentationError: unexpected indent
